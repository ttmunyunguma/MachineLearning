# %%
import pandas as pd
from pandas.plotting import scatter_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %matplotlib inline

# %%
loans = pd.read_csv("/home/terrence/PycharmProjects/MachineLeaningTut/data/loan.csv")
loans.head()
# Out:
#     Interest.Rate  FICO.Score  Loan.Length  Monthly.Income  Loan.Amount
# 6           15.31         670           36         4891.67         6000
# 11          19.72         670           36         3575.00         2000
# 12          14.27         665           36         4250.00        10625
# 13          21.67         670           60        14166.67        28000
# 21          21.98         665           36         6666.67        22000

# %%
plt.figure()
loans = pd.read_csv("/home/terrence/PycharmProjects/MachineLeaningTut/data/loan.csv")
fico = loans['FICO.Score']
fico.hist(bins = 20)

# %%
plt.figure()
loans = pd.read_csv("/home/terrence/PycharmProjects/MachineLeaningTut/data/loan.csv")
x = loans.boxplot('Interest.Rate', 'FICO.Score')
x.set_xticklabels(['630','','','', ' ', '660','','','', ' ', '690','','','', ' ', '720','','','', ' ', '750','','','', ' ', '780','','','', ' ', '810','','','', ' ', '840'])
x.set_xlabel("Interest Rate")
x.set_ylabel("Fico Score %")
x.set_title("Loans Int FC box plot")
# Out:
# Text(0.5, 1.0, 'Loans Int FC box plot')

# %%
loans = pd.read_csv("/home/terrence/PycharmProjects/MachineLeaningTut/data/loan.csv")
scatter_matrix(loans, alpha=0.1, figsize=(10, 10), diagonal='hist')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4087e32e80>,
# ...
#       dtype=object)

# %%
dframe = pd.read_csv("/home/terrence/PycharmProjects/MachineLeaningTut/data/loan.csv")
int_rate = dframe['Interest.Rate']
loan_amt = dframe['Loan.Amount']
fico_score = dframe['FICO.Score']

x1 = np.matrix(fico_score).transpose()
x2 = np.matrix(loan_amt).transpose()
y = np.matrix(int_rate).transpose()
x = np.column_stack([x1, x2])
x3 = sm.add_constant(x)

# %%
model = sm.OLS(y, x3)
model_fit = model.fit()
print("The p_values are: ", model_fit.pvalues)
print("The R^2 value is: ", model_fit.rsquared)
# Out:
# The p_values are:  [0.00000000e+000 0.00000000e+000 5.96972978e-203]
# The R^2 value is:  0.6566326246493588
